# %%
import pandas as pd

df = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/64c6e452-783a-4d71-95e6-22b1cdf96d37', encoding='latin-1', sep=';')
df
# Out:
#       id_zone INSEE_C            LIBGEO       EPCI  DEP  REG  \
# 0           1   86051  Champagné-le-Sec  200070035   86   75
# 1           1   16136           La Faye  200043016   16   75
# 2           1   16002        Les Adjots  200043016   16   75
# 3           1   79150        Limalonges  200069755   79   75
# 4           1   16104            Condac  200043016   16   75
# ...       ...     ...               ...        ...  ...  ...
# 34955   DOM_9   97304            Kourou  200027548  973    3
# 34956   DOM_9   97362        Papaichton  249730037  973    3
# 34957   DOM_9   97358        Saint-Élie  200027548  973    3
# 34958   DOM_9   97353       Maripasoula  249730037  973    3
# 34959   DOM_9   97356            Camopi  249730052  973    3
#
#               loypredm2          lwr.IPm2          upr.IPm2  TYPPRED  \
# 0      8,48108601820233  6,60248185247569  10,8942094284101   maille
# 1      8,48108601820233  6,60248185247569  10,8942094284101   maille
# ...

# %%
df.loc[df['INSEE_C'].str.startswith('17')]
# Out:
#       id_zone INSEE_C                    LIBGEO       EPCI DEP  REG  \
# 1023      105   17463                 Vergeroux  200041762  17   75
# 1024      105   17484          Port-des-Barques  200041762  17   75
# 1025      105   17353  Saint-Laurent-de-la-Prée  200041762  17   75
# 1026      105   17036                  Beaugeay  200041762  17   75
# 1027      105   17205          Loire-les-Marais  200041762  17   75
# ...       ...     ...                       ...        ...  ..  ...
# 34889     997   17151                 L'Éguille  241700640  17   75
# 34890     997   17409    Saint-Sulpice-de-Royan  241700640  17   75
# 34891     997   17311            Saint-Augustin  241700640  17   75
# 34892     997   17380      Saint-Palais-sur-Mer  241700640  17   75
# 34893     997   17064                 Breuillet  241700640  17   75
#
#               loypredm2          lwr.IPm2          upr.IPm2  TYPPRED  \
# 1023   11,7122830631112  9,30672296945332  14,7396215618201   maille
# ...
