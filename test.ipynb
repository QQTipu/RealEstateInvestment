# %% [markdown]
# # Données des loyers

# %%
import pandas as pd

# Import des datasets depuis data gouv pour les appartements 1 et 2 pièces
loyers_2024 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/89956da9-5b9b-41d7-8703-18dbec4d54a2', encoding='latin-1', sep=';')
loyers_2023 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/edadefbc-9707-45ef-a841-283608709e58', encoding='latin-1', sep=';')
loyers_2022 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/7141612b-8029-44a4-a048-921a85a47b1f', encoding='latin-1', sep=';')

# Ajout d'une colonne pour l'année du fichier
loyers_2024['annee'] = 2024
loyers_2023['annee'] = 2023
loyers_2022['annee'] = 2022

# Concaténer les données des loyers
loyers_full = pd.concat([loyers_2024, loyers_2023, loyers_2022], ignore_index=True)

# %% [markdown]
# ## Exploration des loyers

# %%
loyers_full.loc[loyers_full['LIBGEO'].str.contains('Nieul-sur-Mer')]
# Out:
#        id_zone INSEE_C         LIBGEO       EPCI DEP  REG         loypredm2  \
# 8864      1611   17264  Nieul-sur-Mer  241700434  17   75  15,6973097566384
# 45882      205   17264  Nieul-sur-Mer  241700434  17   75  12,8882274829193
# 103147     913   17264  Nieul-sur-Mer  241700434  17   75   14,142377590729
#
#                 lwr.IPm2          upr.IPm2 TYPPRED  nbobs_com  nbobs_mail  \
# 8864    12,4269528532851  19,8283148334885  maille         52       10361
# 45882    10,276902661019   16,163080757934  maille         48         488
# 103147  11,7009080982947  17,0932753456889  maille         45         526
#
#                    R2_adj  annee
# 8864     0,65007636150723   2024
# 45882   0,748866015585573   2023
# 103147   0,61533015740466   2022

# %%
loyers_full.loc[loyers_full['LIBGEO'].str.contains('Lagord')]
# Out:
#        id_zone INSEE_C  LIBGEO       EPCI DEP  REG         loypredm2  \
# 8859      1611   17200  Lagord  241700434  17   75  16,4447819095013
# 41196     1376   17200  Lagord  241700434  17   75  15,6198503451144
# 103155     913   17200  Lagord  241700434  17   75   14,142377590729
#
#                 lwr.IPm2          upr.IPm2  TYPPRED  nbobs_com  nbobs_mail  \
# 8859    12,9646727015379  20,8590573998046  commune        115       10361
# 41196   12,3390878291948  19,7729141879114  commune        108        9189
# 103155  11,7009080982947  17,0932753456889   maille         78         526
#
#                    R2_adj  annee
# 8859     0,65007636150723   2024
# 41196   0,641281499725126   2023
# 103155   0,61533015740466   2022

# %%
loyers_full.loc[loyers_full['LIBGEO'].str.contains('Poitiers')]
# Out:
#       id_zone INSEE_C    LIBGEO       EPCI DEP  REG         loypredm2  \
# 9915      172   86194  Poitiers  200069854  86   75  13,5127623775767
# 62829      71   86194  Poitiers  200069854  86   75  13,2469884817449
# 71077    1047   86194  Poitiers  200069854  86   75  14,0771472018662
#
#                lwr.IPm2          upr.IPm2  TYPPRED  nbobs_com  nbobs_mail  \
# 9915   11,0001397089263  16,5993116364407  commune      22765       22983
# 62829  10,8178438328651   16,221597071161  commune      20335       21353
# 71077  11,4781525322722  17,2646314627587  commune      17544       17771
#
#                   R2_adj  annee
# 9915   0,743015750534266   2024
# 62829   0,74601894196153   2023
# 71077  0,741450878832318   2022

# %%
loyers_full.loc[loyers_full['LIBGEO'].str.contains('Mérignac') & loyers_full['INSEE_C'].str.contains('33281')]
# Out:
#       id_zone INSEE_C    LIBGEO       EPCI DEP  REG         loypredm2  \
# 7463     1473   33281  Mérignac  243300316  33   75  17,3211307731372
# 45043    1859   33281  Mérignac  243300316  33   75  16,8353834324416
# 76332    1451   33281  Mérignac  243300316  33   75  16,6314695477889
#
#                lwr.IPm2          upr.IPm2  TYPPRED  nbobs_com  nbobs_mail  \
# 7463   14,5231792360587  20,6581194367701  commune       6853        7051
# 45043  14,0099460091962  20,2306372295286  commune       4021        4021
# 76332   12,982729355201  21,3056724631034  commune       3656       35464
#
#                   R2_adj  annee
# 7463   0,628501351976129   2024
# 45043  0,614830898027762   2023
# 76332  0,609933135175862   2022

# %% [markdown]
# # Données des valeurs foncières

# %%
# Import des données depuis data gouv
dvf_2024 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/5ffa8553-0e8f-4622-add9-5c0b593ca1f8', compression='zip', encoding='latin-1', sep='|').dropna()
# Out:
# C:\Users\Thibaut\AppData\Local\Temp\ipykernel_19124\641464688.py:2: DtypeWarning: Columns (14,18,23,24,26,28,29,30,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   dvf_2024 = pd.read_csv('https://www.data.gouv.fr/fr/datasets/r/5ffa8553-0e8f-4622-add9-5c0b593ca1f8', compression='zip', encoding='latin-1', sep='|').dropna()

# %%
display(dvf_2024.head(10), dvf_2024.columns)
# Out:
#    Identifiant de document  Reference document  1 Articles CGI  \
# 0                      NaN                 NaN             NaN
# 1                      NaN                 NaN             NaN
# 2                      NaN                 NaN             NaN
# 3                      NaN                 NaN             NaN
# 4                      NaN                 NaN             NaN
# 5                      NaN                 NaN             NaN
# 6                      NaN                 NaN             NaN
# 7                      NaN                 NaN             NaN
# 8                      NaN                 NaN             NaN
# 9                      NaN                 NaN             NaN
#
#    2 Articles CGI  3 Articles CGI  4 Articles CGI  5 Articles CGI  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
# 5             NaN             NaN             NaN             NaN
# 6             NaN             NaN             NaN             NaN
# 7             NaN             NaN             NaN             NaN
# 8             NaN             NaN             NaN             NaN
# 9             NaN             NaN             NaN             NaN
#
#    No disposition Date mutation Nature mutation  ...  \
# 0               1    02/01/2024           Vente  ...
# 1               2    03/01/2024           Vente  ...
# 2               1    08/01/2024           Vente  ...
# 3               1    03/01/2024           Vente  ...
# 4               1    03/01/2024           Vente  ...
# 5               1    03/01/2024           Vente  ...
# 6               1    03/01/2024           Vente  ...
# 7               1    09/01/2024           Vente  ...
# 8               1    09/01/2024           Vente  ...
# 9               1    09/01/2024           Vente  ...
#
#   Surface Carrez du 5eme lot  Nombre de lots Code type local   Type local  \
# 0                        NaN               0             NaN          NaN
# 1                        NaN               0             NaN          NaN
# 2                        NaN               0             NaN          NaN
# 3                        NaN               1             3.0  DÃ©pendance
# 4                        NaN               2             3.0  DÃ©pendance
# 5                        NaN               2             3.0  DÃ©pendance
# 6                        NaN               2             2.0  Appartement
# 7                        NaN               0             NaN          NaN
# 8                        NaN               0             NaN          NaN
# 9                        NaN               0             NaN          NaN
#
#   Identifiant local Surface reelle bati  Nombre pieces principales  \
# 0               NaN                 NaN                        NaN
# 1               NaN                 NaN                        NaN
# 2               NaN                 NaN                        NaN
# 3               NaN                 0.0                        0.0
# 4               NaN                 0.0                        0.0
# 5               NaN                 0.0                        0.0
# 6               NaN                89.0                        4.0
# 7               NaN                 NaN                        NaN
# 8               NaN                 NaN                        NaN
# 9               NaN                 NaN                        NaN
#
#   Nature culture Nature culture speciale  Surface terrain
# 0              P                     NaN             99.0
# 1              S                     NaN            115.0
# 2              S                     NaN            497.0
# 3            NaN                     NaN              NaN
# 4            NaN                     NaN              NaN
# 5            NaN                     NaN              NaN
# 6            NaN                     NaN              NaN
# 7             BR                     NaN           1584.0
# 8             BR                     NaN            188.0
# 9             BR                     NaN           2532.0
#
# [10 rows x 43 columns]
# Index(['Identifiant de document', 'Reference document', '1 Articles CGI',
#        '2 Articles CGI', '3 Articles CGI', '4 Articles CGI', '5 Articles CGI',
#        'No disposition', 'Date mutation', 'Nature mutation', 'Valeur fonciere',
#        'No voie', 'B/T/Q', 'Type de voie', 'Code voie', 'Voie', 'Code postal',
#        'Commune', 'Code departement', 'Code commune', 'Prefixe de section',
#        'Section', 'No plan', 'No Volume', '1er lot',
#        'Surface Carrez du 1er lot', '2eme lot', 'Surface Carrez du 2eme lot',
#        '3eme lot', 'Surface Carrez du 3eme lot', '4eme lot',
#        'Surface Carrez du 4eme lot', '5eme lot', 'Surface Carrez du 5eme lot',
#        'Nombre de lots', 'Code type local', 'Type local', 'Identifiant local',
#        'Surface reelle bati', 'Nombre pieces principales', 'Nature culture',
#        'Nature culture speciale', 'Surface terrain'],
#       dtype='object')

# %%
df = dvf_2024.loc[
    (dvf_2024['Nature mutation'].str.contains('vente', case=False))
    & (dvf_2024['Type local'].str.contains('appartement', case=False))
    & (dvf_2024['Nombre de lots'] == 1)
    & (dvf_2024['Nombre pieces principales'] <= 2)
]
df[['Date mutation', 'Nature mutation', 'Type local', 'Nombre pieces principales', 'Valeur fonciere', 'Code postal','Commune', 'Code departement', 'Code commune', '1er lot', 'Surface Carrez du 1er lot']]
# Out:
# Empty DataFrame
# Columns: [Date mutation, Nature mutation, Type local, Nombre pieces principales, Valeur fonciere, Code postal, Commune, Code departement, Code commune, 1er lot, Surface Carrez du 1er lot]
# Index: []
